# %%
from src.experiments import EXPERIMENTS, prepare_mixed_yamls

prepare_mixed_yamls(EXPERIMENTS)
# Out:
# Total imágenes en all: 3262 | Usando: 3262 (100.0%)
# Config YOLO creada:
#   YAML:   C:\Users\bianc\Vision\tpf\configs\detrac_mixed_raw.yaml
#   train:  C:\Users\bianc\Vision\tpf\configs\detrac_mixed_raw_train.txt (2609 imágenes)
#   val:    C:\Users\bianc\Vision\tpf\configs\detrac_mixed_raw_val.txt (653 imágenes)
# [raw] YAML listo:
#    yaml:  C:\Users\bianc\Vision\tpf\configs\detrac_mixed_raw.yaml
#    train: C:\Users\bianc\Vision\tpf\configs\detrac_mixed_raw_train.txt
#    val:   C:\Users\bianc\Vision\tpf\configs\detrac_mixed_raw_val.txt
# Total imágenes en all: 3262 | Usando: 3262 (100.0%)
# Config YOLO creada:
#   YAML:   C:\Users\bianc\Vision\tpf\configs\detrac_mixed_clahe.yaml
#   train:  C:\Users\bianc\Vision\tpf\configs\detrac_mixed_clahe_train.txt (2609 imágenes)
#   val:    C:\Users\bianc\Vision\tpf\configs\detrac_mixed_clahe_val.txt (653 imágenes)
# [clahe] YAML listo:
#    yaml:  C:\Users\bianc\Vision\tpf\configs\detrac_mixed_clahe.yaml
# ...

# %%
from src.experiments import train_all_experiments, EXPERIMENTS

# Ajustá epochs/batch si te explota la GPU
train_all_experiments(
    experiments=EXPERIMENTS,
    base_weights="yolo11s.pt",
    epochs=5,
    imgsz=640,
    batch=4,
    project="runs",
)
# Out:
# ================= Entrenando experimento: raw =================
# Ultralytics 8.3.228  Python-3.11.2 torch-2.7.0+cpu CPU (11th Gen Intel Core i5-1135G7 @ 2.40GHz)
# ...

# %%
from src.experiments import collect_experiments_metrics, plot_experiments_metrics, EXPERIMENTS

metrics_df = collect_experiments_metrics(EXPERIMENTS)
metrics_df
plot_experiments_metrics(metrics_df)

# %%
from src.experiments import qualitative_comparison_on_archive, EXPERIMENTS

qualitative_comparison_on_archive(
    experiments=EXPERIMENTS,
    runs_base_dir=r"runs/detect",
    n_images=6,
    conf=0.25,
)
